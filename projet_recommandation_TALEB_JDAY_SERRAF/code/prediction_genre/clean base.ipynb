# %%
import save as sv
import pandas as pd

# %%
df = sv.lectureFichier('./data_clean_personaliser')

# %%
df
# Out:
#                  reviewer                   movie rating
# 0              sharonrota                             10
# 1       moviereviewer6700      brooklyn nine nine     10
# 2              nadyaruray                 kingdom      6
# 3            drszilviavas                    code     10
# 4           tierney-steve       the invisible man      2
# ...                   ...                     ...    ...
# 440770              nferr  quatermass and the pit      6
# 440771              m-fan  quatermass and the pit      9
# 440772        mw_director  quatermass and the pit      9
# 440773          Snake-666  quatermass and the pit      8
# 440774      henry-girling  quatermass and the pit      8
#
# [440775 rows x 3 columns]

# %%
df1 = pd.read_csv('data.csv')

# %%
df1
# Out:
#                             Series Title  Year Released Content Rating  \
# 0                           Breaking Bad           2008            18+
# 1                        Game of Thrones           2011            18+
# 2                         Rick and Morty           2013            18+
# 3                        Stranger Things           2016            16+
# 4                               The Boys           2019            18+
# ...                                  ...            ...            ...
# 12348  A Fishing Story with Ronnie Green           2017            NaN
# 12349                  CMT Most Shocking           2003            NaN
# 12350   NHL Road to the Outdoor Classics           2016            NaN
# 12351                         Addy Media           2018            NaN
# 12352             My Dream Derelict Home           2014            NaN
#
#        R Rating                      Genre  \
# 0           100                Crime,Drama
# ...

# %%
df1["Series Title"]=df1["Series Title"].str.lower()

# %%
df1
# Out:
#                             Series Title  Year Released Content Rating  \
# 0                           breaking bad           2008            18+
# 1                        game of thrones           2011            18+
# 2                         rick and morty           2013            18+
# 3                        stranger things           2016            16+
# 4                               the boys           2019            18+
# ...                                  ...            ...            ...
# 12348  a fishing story with ronnie green           2017            NaN
# 12349                  cmt most shocking           2003            NaN
# 12350   nhl road to the outdoor classics           2016            NaN
# 12351                         addy media           2018            NaN
# 12352             my dream derelict home           2014            NaN
#
#        R Rating                      Genre  \
# 0           100                Crime,Drama
# ...

# %%
df
# Out:
#                  reviewer                   movie rating
# 0              sharonrota                             10
# 1       moviereviewer6700      brooklyn nine nine     10
# 2              nadyaruray                 kingdom      6
# 3            drszilviavas                    code     10
# 4           tierney-steve       the invisible man      2
# ...                   ...                     ...    ...
# 440770              nferr  quatermass and the pit      6
# 440771              m-fan  quatermass and the pit      9
# 440772        mw_director  quatermass and the pit      9
# 440773          Snake-666  quatermass and the pit      8
# 440774      henry-girling  quatermass and the pit      8
#
# [440775 rows x 3 columns]

# %%
df1 = df1.rename(columns={'Series Title':'movie'})

# %%
df1
# Out:
#                                    movie  Year Released Content Rating  \
# 0                           breaking bad           2008            18+
# 1                        game of thrones           2011            18+
# 2                         rick and morty           2013            18+
# 3                        stranger things           2016            16+
# 4                               the boys           2019            18+
# ...                                  ...            ...            ...
# 12348  a fishing story with ronnie green           2017            NaN
# 12349                  cmt most shocking           2003            NaN
# 12350   nhl road to the outdoor classics           2016            NaN
# 12351                         addy media           2018            NaN
# 12352             my dream derelict home           2014            NaN
#
#        R Rating                      Genre  \
# 0           100                Crime,Drama
# ...

# %%
df.merge(df1, how='inner', on='movie')
# Out:
#                    reviewer             movie rating  Year Released  \
# 0                nadyaruray           kingdom      6           2019
# 1                nadyaruray           kingdom      6           2014
# 2                nadyaruray           kingdom      6           2007
# 3                nadyaruray           kingdom      6           2012
# 4             redhawk-70707           kingdom      5           2019
# ...                     ...               ...    ...            ...
# 262270         ianlouisiana       in the club      4           2014
# 262271         hillrosemary       in the club      9           2014
# 262272        Sunshine_pink       in the club      1           2014
# 262273          darshangood  pete versus life     10           2010
# 262274  hashtagtechnobabble       newsreaders     10           2013
#
#        Content Rating  R Rating                     Genre  \
# 0                 18+        85  Action & Adventure,Drama
# ...

# %%
df = df.merge(df1, how='inner', on='movie').drop(columns=['Year Released','Content Rating','Description','No of Seasons','Streaming Platform'])

# %%
df = df.rename(columns={"R Rating":'global rating', "Genre":'genre'})

# %%
df
# Out:
#                    reviewer             movie rating  global rating  \
# 0                nadyaruray           kingdom      6             85
# 1                nadyaruray           kingdom      6             83
# 2                nadyaruray           kingdom      6             58
# 3                nadyaruray           kingdom      6             56
# 4             redhawk-70707           kingdom      5             85
# ...                     ...               ...    ...            ...
# 262270         ianlouisiana       in the club      4             46
# 262271         hillrosemary       in the club      9             46
# 262272        Sunshine_pink       in the club      1             46
# 262273          darshangood  pete versus life     10             37
# 262274  hashtagtechnobabble       newsreaders     10             48
#
#                            genre
# 0       Action & Adventure,Drama
# 1                    Drama,Sport
# 2                   Drama,Comedy
# ...

# %%
sv.sauvegardeFichier("base_de_donnees",df)
